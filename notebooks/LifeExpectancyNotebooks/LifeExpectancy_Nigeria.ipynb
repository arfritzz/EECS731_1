# %% [markdown]
# ### Purpose

# %% [markdown]
# The purpose of this notebook was to take the data found in the `LifeExpectancyAtBirth` folder and analyze it for Nigeria.

# %% [markdown]
# ### Findings

# %% [markdown]
# The graph at the bottom of the notebook shows that the average age of a Nigerian citizen has been increasing through the past 15 years.

# %%
import numpy as np

# %%
import pandas as pd

# %%
life = pd.read_csv('~/Documents/EECS/EECS_731/HW/EECS731_1/data/LifeExpectancyAtBirth/data.csv', skiprows=3)

# %%
life.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', 'Unnamed: 64'],
#       dtype='object')

# %%
life = life.drop(columns="Country Code")

# %%
life = life.drop(columns="Indicator Name")

# %%
life = life.drop(columns="Indicator Code")

# %%
life= life.drop(life.loc[:,'1960':'2000'].columns, axis=1)

# %%
life
# Out:
#      Country Name       2001       2002       2003       2004       2005  \
# 0           Aruba  73.853000  73.937000  74.038000  74.156000  74.287000
# 1     Afghanistan  56.308000  56.784000  57.271000  57.772000  58.290000
# 2          Angola  47.059000  47.702000  48.440000  49.263000  50.165000
# 3         Albania  74.288000  74.579000  74.828000  75.039000  75.228000
# 4         Andorra        NaN        NaN        NaN        NaN        NaN
# ..            ...        ...        ...        ...        ...        ...
# 259        Kosovo  67.997561  67.943902  68.195122  68.446341  68.695122
# 260   Yemen, Rep.  61.216000  61.781000  62.358000  62.931000  63.481000
# 261  South Africa  55.089000  54.310000  53.749000  53.444000  53.447000
# 262        Zambia  44.615000  45.400000  46.322000  47.354000  48.496000
# 263      Zimbabwe  44.010000  43.523000  43.195000  43.065000  43.241000
#
#           2006       2007       2008      2009  ...      2011       2012  \
# 0    74.429000  74.576000  74.725000  74.87200  ...  75.15800  75.299000
# 1    58.826000  59.375000  59.930000  60.48400  ...  61.55300  62.054000
# 2    51.143000  52.177000  53.243000  54.31100  ...  56.33000  57.236000
# 3    75.423000  75.646000  75.912000  76.22100  ...  76.91400  77.252000
# 4          NaN        NaN        NaN       NaN  ...       NaN        NaN
# ..         ...        ...        ...       ...  ...       ...        ...
# 259  68.946341  69.197561  69.397561  69.64878  ...  70.14878  70.497561
# 260  63.997000  64.470000  64.892000  65.25500  ...  65.76800  65.920000
# 261  53.795000  54.452000  55.360000  56.46000  ...  58.89500  60.060000
# 262  49.757000  51.134000  52.606000  54.13000  ...  57.12600  58.502000
# 263  43.853000  44.947000  46.504000  48.44900  ...  52.89600  55.032000
#
#           2013       2014       2015       2016       2017       2018  2019  \
# 0    75.441000  75.583000  75.725000  75.868000  76.010000  76.152000   NaN
# 1    62.525000  62.966000  63.377000  63.763000  64.130000  64.486000   NaN
# 2    58.054000  58.776000  59.398000  59.925000  60.379000  60.782000   NaN
# 3    77.554000  77.813000  78.025000  78.194000  78.333000  78.458000   NaN
# 4          NaN        NaN        NaN        NaN        NaN        NaN   NaN
# ..         ...        ...        ...        ...        ...        ...   ...
# 259  70.797561  71.097561  71.346341  71.646341  71.946341  72.195122   NaN
# 260  66.016000  66.066000  66.085000  66.087000  66.086000  66.096000   NaN
# 261  61.099000  61.968000  62.649000  63.153000  63.538000  63.857000   NaN
# 262  59.746000  60.831000  61.737000  62.464000  63.043000  63.510000   NaN
# 263  56.897000  58.410000  59.534000  60.294000  60.812000  61.195000   NaN
#
#      Unnamed: 64
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 259          NaN
# 260          NaN
# 261          NaN
# 262          NaN
# 263          NaN
#
# [264 rows x 21 columns]

# %%
life = life[life["Country Name"] == "Nigeria"]

# %%
life
# Out:
#     Country Name   2001    2002    2003   2004    2005    2006    2007  \
# 172      Nigeria  46.51  46.835  47.242  47.72  48.252  48.812  49.373
#
#        2008    2009  ...    2011    2012    2013    2014    2015    2016  \
# 172  49.913  50.422  ...  51.346  51.786  52.228  52.672  53.112  53.541
#
#       2017    2018  2019  Unnamed: 64
# 172  53.95  54.332   NaN          NaN
#
# [1 rows x 21 columns]

# %%
life = life.drop(columns="Unnamed: 64")

# %%
life= life.drop(life.loc[:,'2018':'2019'].columns, axis=1)

# %%
life = life.replace('', np.nan).set_index('Country Name').stack().reset_index(name='Average Age').drop('level_1',1)

# %%
life
# Out:
#    Country Name  Average Age
# 0       Nigeria       46.510
# 1       Nigeria       46.835
# 2       Nigeria       47.242
# 3       Nigeria       47.720
# 4       Nigeria       48.252
# 5       Nigeria       48.812
# 6       Nigeria       49.373
# 7       Nigeria       49.913
# 8       Nigeria       50.422
# 9       Nigeria       50.896
# 10      Nigeria       51.346
# 11      Nigeria       51.786
# 12      Nigeria       52.228
# 13      Nigeria       52.672
# 14      Nigeria       53.112
# 15      Nigeria       53.541
# 16      Nigeria       53.950

# %%
life.insert(2,"Year", [2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017], True)

# %%
life
# Out:
#    Country Name  Average Age  Year
# 0       Nigeria       46.510  2001
# 1       Nigeria       46.835  2002
# 2       Nigeria       47.242  2003
# 3       Nigeria       47.720  2004
# 4       Nigeria       48.252  2005
# 5       Nigeria       48.812  2006
# 6       Nigeria       49.373  2007
# 7       Nigeria       49.913  2008
# 8       Nigeria       50.422  2009
# 9       Nigeria       50.896  2010
# 10      Nigeria       51.346  2011
# 11      Nigeria       51.786  2012
# 12      Nigeria       52.228  2013
# 13      Nigeria       52.672  2014
# 14      Nigeria       53.112  2015
# 15      Nigeria       53.541  2016
# 16      Nigeria       53.950  2017

# %%
life.plot(y='Average Age', x='Year')

# %%
life
# Out:
#    Country Name  Average Age  Year
# 0       Nigeria       46.510  2001
# 1       Nigeria       46.835  2002
# 2       Nigeria       47.242  2003
# 3       Nigeria       47.720  2004
# 4       Nigeria       48.252  2005
# 5       Nigeria       48.812  2006
# 6       Nigeria       49.373  2007
# 7       Nigeria       49.913  2008
# 8       Nigeria       50.422  2009
# 9       Nigeria       50.896  2010
# 10      Nigeria       51.346  2011
# 11      Nigeria       51.786  2012
# 12      Nigeria       52.228  2013
# 13      Nigeria       52.672  2014
# 14      Nigeria       53.112  2015
# 15      Nigeria       53.541  2016
# 16      Nigeria       53.950  2017

# %%
life.to_csv('life_N.csv')

# %% [markdown]
# I exported the data to a new file so it would be easier to combine. This new file is called `life_N` and can be found in the `data` folder.
