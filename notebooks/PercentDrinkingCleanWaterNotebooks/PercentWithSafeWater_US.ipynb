# %% [markdown]
# ### Purpose
#
# The purpose of this notebook was to analyze the data that details the percentages of citizens around the world who have access to safe drinking water. This notebook specifically analyzes the trend in the amount of people who have safe drinking water in United Stated.
#
# ### Findings
#
# As the final figure shows, the amount of people who have access to safe drinking water has remained constant over the past decade at around 99% having access to safe drinking water.

# %%
import pandas as pd

# %%
import numpy as np

# %%
water = pd.read_csv('~/Documents/EECS/EECS_731/HW/EECS731_1/data/PeopleUsingSafeWater/water.csv', skiprows=3)

# %%
water
# Out:
#      Country Name Country Code  \
# 0           Aruba          ABW
# 1     Afghanistan          AFG
# 2          Angola          AGO
# 3         Albania          ALB
# 4         Andorra          AND
# ..            ...          ...
# 259        Kosovo          XKX
# 260   Yemen, Rep.          YEM
# 261  South Africa          ZAF
# 262        Zambia          ZMB
# 263      Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  1960  \
# 0    People using safely managed drinking water ser...  SH.H2O.SMDW.ZS   NaN
# 1    People using safely managed drinking water ser...  SH.H2O.SMDW.ZS   NaN
# 2    People using safely managed drinking water ser...  SH.H2O.SMDW.ZS   NaN
# 3    People using safely managed drinking water ser...  SH.H2O.SMDW.ZS   NaN
# 4    People using safely managed drinking water ser...  SH.H2O.SMDW.ZS   NaN
# ..                                                 ...             ...   ...
# ...

# %%
water.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2016              float64
# 2017              float64
# 2018              float64
# 2019              float64
# Unnamed: 64       float64
# Length: 65, dtype: object

# %%
water = water.drop(columns="Indicator Code")

# %%
water = water.drop(columns="Country Code")

# %%
water = water.drop(columns="Indicator Name")

# %%
water
# Out:
#      Country Name  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...  \
# 0           Aruba   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1     Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2          Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3         Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4         Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ..            ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 259        Kosovo   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 260   Yemen, Rep.   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 261  South Africa   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 262        Zambia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 263      Zimbabwe   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
# ...

# %%
water[water["Country Name"] == "United States"]
# Out:
#       Country Name  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...  \
# 249  United States   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#           2011       2012       2013       2014       2015      2016  \
# 249  98.970687  98.975572  98.980598  98.985731  98.990978  98.99631
#
#           2017  2018  2019  Unnamed: 64
# 249  99.001778   NaN   NaN          NaN
#
# [1 rows x 62 columns]

# %%
water = water.drop(columns=['1961'])

# %%
water
# Out:
#      Country Name  1960  1962  1963  1964  1965  1966  1967  1968  1969  ...  \
# 0           Aruba   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1     Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2          Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3         Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4         Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ..            ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 259        Kosovo   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 260   Yemen, Rep.   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 261  South Africa   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 262        Zambia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 263      Zimbabwe   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
# ...

# %%
water = water.drop(water.loc[:,'1962':'2000'].columns, axis=1)

# %%
water = water.drop(columns=['1960'])

# %%
water
# Out:
#      Country Name       2001       2002       2003       2004       2005  \
# 0           Aruba        NaN        NaN        NaN        NaN        NaN
# 1     Afghanistan        NaN        NaN        NaN        NaN        NaN
# 2          Angola        NaN        NaN        NaN        NaN        NaN
# 3         Albania  49.217383  49.081537  48.942255  50.734758  52.551151
# 4         Andorra  90.639997  90.639996  90.640002  90.639997  90.639999
# ..            ...        ...        ...        ...        ...        ...
# 259        Kosovo        NaN        NaN        NaN        NaN        NaN
# 260   Yemen, Rep.        NaN        NaN        NaN        NaN        NaN
# 261  South Africa        NaN        NaN        NaN        NaN        NaN
# 262        Zambia        NaN        NaN        NaN        NaN        NaN
# 263      Zimbabwe        NaN        NaN        NaN        NaN        NaN
#
#           2006       2007       2008       2009  ...       2011       2012  \
# ...

# %%
water = water.drop(water.loc[:,'2018':'2019'].columns, axis=1)

# %%
water = water.drop(columns=['Unnamed: 64'])

# %%
water
# Out:
#      Country Name       2001       2002       2003       2004       2005  \
# 0           Aruba        NaN        NaN        NaN        NaN        NaN
# 1     Afghanistan        NaN        NaN        NaN        NaN        NaN
# 2          Angola        NaN        NaN        NaN        NaN        NaN
# 3         Albania  49.217383  49.081537  48.942255  50.734758  52.551151
# 4         Andorra  90.639997  90.639996  90.640002  90.639997  90.639999
# ..            ...        ...        ...        ...        ...        ...
# 259        Kosovo        NaN        NaN        NaN        NaN        NaN
# 260   Yemen, Rep.        NaN        NaN        NaN        NaN        NaN
# 261  South Africa        NaN        NaN        NaN        NaN        NaN
# 262        Zambia        NaN        NaN        NaN        NaN        NaN
# 263      Zimbabwe        NaN        NaN        NaN        NaN        NaN
#
#           2006       2007       2008       2009       2010       2011  \
# ...

# %%
water = water[water["Country Name"] == "United States"]

# %%
water
# Out:
#       Country Name  2001  2002  2003  2004       2005       2006       2007  \
# 249  United States   NaN   NaN   NaN   NaN  98.942332  98.947103  98.951852
#
#           2008       2009       2010       2011       2012       2013  \
# 249  98.956569  98.961258  98.965887  98.970687  98.975572  98.980598
#
#           2014       2015      2016       2017
# 249  98.985731  98.990978  98.99631  99.001778

# %%
water.dtypes
# Out:
# Country Name     object
# 2001            float64
# 2002            float64
# 2003            float64
# 2004            float64
# 2005            float64
# 2006            float64
# 2007            float64
# 2008            float64
# 2009            float64
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# dtype: object

# %%
water['2010']
# Out:
# 249    98.965887
# Name: 2010, dtype: float64

# %%
water.to_csv('water_US.csv')

# %%
water.columns
# Out:
# Index(['Country Name', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017'],
#       dtype='object')

# %%
water = water.replace('', np.nan).set_index('Country Name').stack().reset_index(name='Percent Safe Water').drop('level_1',1)

# %%
water
# Out:
#      Country Name  Percent Safe Water
# 0   United States           98.942332
# 1   United States           98.947103
# 2   United States           98.951852
# 3   United States           98.956569
# 4   United States           98.961258
# 5   United States           98.965887
# 6   United States           98.970687
# 7   United States           98.975572
# 8   United States           98.980598
# 9   United States           98.985731
# 10  United States           98.990978
# 11  United States           98.996310
# 12  United States           99.001778

# %%
water
# Out:
#      Country Name  Percent Safe Water
# 0   United States           98.942332
# 1   United States           98.947103
# 2   United States           98.951852
# 3   United States           98.956569
# 4   United States           98.961258
# 5   United States           98.965887
# 6   United States           98.970687
# 7   United States           98.975572
# 8   United States           98.980598
# 9   United States           98.985731
# 10  United States           98.990978
# 11  United States           98.996310
# 12  United States           99.001778

# %%
water.insert(2,"Year", [2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017], True)

# %%
water
# Out:
#      Country Name  Percent Safe Water  Year
# 0   United States           98.942332  2005
# 1   United States           98.947103  2006
# 2   United States           98.951852  2007
# 3   United States           98.956569  2008
# 4   United States           98.961258  2009
# 5   United States           98.965887  2010
# 6   United States           98.970687  2011
# 7   United States           98.975572  2012
# 8   United States           98.980598  2013
# 9   United States           98.985731  2014
# 10  United States           98.990978  2015
# 11  United States           98.996310  2016
# 12  United States           99.001778  2017

# %%
water.plot.scatter(y='Percent Safe Water', x='Year')

# %%
water.plot(y='Percent Safe Water', x='Year', ylim=[80,100] )

# %%
water.to_csv('water_US.csv')
